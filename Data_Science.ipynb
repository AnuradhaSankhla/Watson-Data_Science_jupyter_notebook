# %% [markdown]
# # My Jupyter Notebook On Watson Studio

# %% [markdown]
# **Name :- Anuradha Rajkrishna Sankhla**
#
# Occupation :- Data Analyst

# %% [markdown]
# * I am interested in data science because, I have a passion for using
#  data to draw meaningful conclusions about a companys growth.
#  I enjoy being a part of new technologies and trying out innovations, which I've noticed your company also values*

# %% [markdown]
# ### Addition of Two Numbers

# %%
6+7
# Out:
# 13

# %% [markdown]
# [Skills Network](https://www.coursera.org/?skipBrowseRedirect=true)

# %% [markdown]
# LOGO: ![This is the skills network logo](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png)

# %% [markdown]
# | Country Name | Capital |
# | -------------| ------ |
# | United States | Washington DC |
# | Australia | Canberra |
# | India | New Delhi |
